# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishek17704/learning-git/blob/master/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas**

# %%
import numpy as np
import pandas as pd

# %%
countries = ['India','France','England']
capitals = ['New Delhi','Paris','Londan']
pd.Series (data = capitals, index = countries, name = 'Country Capitals')
# Out:
# India      New Delhi
# France         Paris
# England       Londan
# Name: Country Capitals, dtype: object

# %%
MyDictionary = {'a':100,'b':200,'c':300,'d':400,'e':500}
pd.Series(MyDictionary)
# Out:
# a    100
# b    200
# c    300
# d    400
# e    500
# dtype: int64

# %% [markdown]
# **`From the Above method we learn , how to import Pandas and create series.`**

# %%
MyDictionary
# Out:
# {'a': 100, 'b': 200, 'c': 300, 'd': 400, 'e': 500}

# %%
MySeries = pd.Series(MyDictionary)
MySeries.shape
# Out:
# (5,)

# %%
MySeries
# Out:
# a    100
# b    200
# c    300
# d    400
# e    500
# dtype: int64

# %%
MySeries["b"]
# Out:
# 200

# %% [markdown]
# **`DataFrame`**

# %%
import pandas as pd
data = {'countries':['Belgium','India','Brazil'],
        'capital':['Brussels','New Delhi','Brassila'],
        'popilation':[110000,220000,330000]}
df=pd.DataFrame(data)
print(df)
# Out:
#   countries    capital  popilation
# 0   Belgium   Brussels      110000
# 1     India  New Delhi      220000
# 2    Brazil   Brassila      330000

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
team = [['Nitin K Gupta',20480000,'VP'],['Amit Sati',20480001,'AVP'],['Sneha Padiyar',20480002,'AVP'],['Anshul Saini',20480003,'SM'],
        ['Rajat Puri',20480004,'SM'],['Neha Juneja',20480005,'M'],['Pallavi Bhasin',20480006,'M'],['Amit Garg',20480007,'M'],
        ['Abhishek Gupta',20480008,'M'],['Arun Sharma',20480009,'M'],['Shikha Gandhi',20480010,'AM']]
team_df=pd.DataFrame(data=team,columns=['Name','Employee ID','Designation'])
print(team_df)
# Out:
#               Name  Employee ID Designation
# 0    Nitin K Gupta     20480000          VP
# 1        Amit Sati     20480001         AVP
# 2    Sneha Padiyar     20480002         AVP
# 3     Anshul Saini     20480003          SM
# 4       Rajat Puri     20480004          SM
# 5      Neha Juneja     20480005           M
# 6   Pallavi Bhasin     20480006           M
# 7        Amit Garg     20480007           M
# 8   Abhishek Gupta     20480008           M
# 9      Arun Sharma     20480009           M
# 10   Shikha Gandhi     20480010          AM

# %% [markdown]
# **`Read data from files`**

# %%
import pandas as pd
MyRun = ['Abhishek',20487250,'Manger']
MyRun
print (type(MyRun))
# Out:
# <class 'list'>

# %%
import pandas as pd
readcsv = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Casestudy/supermarkets.csv')
readcsv
# Out:
#    ID          Address           City  ... Country         Name Employees
# 0   1     3666 21st St  San Francisco  ...     USA      Madeira         8
# 1   2   735 Dolores St  San Francisco  ...     USA  Bready Shop        15
# 2   3      332 Hill St  San Francisco  ...     USA  Super River        25
# 3   4     3995 23rd St  San Francisco  ...     USA   Ben's Shop        10
# 4   5  1056 Sanchez St  San Francisco  ...     USA      Sanchez        12
# 5   6  551 Alvarado St  San Francisco  ...     USA   Richvalley        20
#
# [6 rows x 7 columns]

# %%
readcsv['Salary']=[110000,220000,330000,440000,550000,660000]
readcsv
# Out:
#    ID          Address           City  ...         Name Employees  Salary
# 0   1     3666 21st St  San Francisco  ...      Madeira         8  110000
# 1   2   735 Dolores St  San Francisco  ...  Bready Shop        15  220000
# 2   3      332 Hill St  San Francisco  ...  Super River        25  330000
# 3   4     3995 23rd St  San Francisco  ...   Ben's Shop        10  440000
# 4   5  1056 Sanchez St  San Francisco  ...      Sanchez        12  550000
# 5   6  551 Alvarado St  San Francisco  ...   Richvalley        20  660000
#
# [6 rows x 8 columns]

# %%
readcsv
# Out:
#    ID          Address           City  ... Country         Name Employees
# 0   1     3666 21st St  San Francisco  ...     USA      Madeira         8
# 1   2   735 Dolores St  San Francisco  ...     USA  Bready Shop        15
# 2   3      332 Hill St  San Francisco  ...     USA  Super River        25
# 3   4     3995 23rd St  San Francisco  ...     USA   Ben's Shop        10
# 4   5  1056 Sanchez St  San Francisco  ...     USA      Sanchez        12
# 5   6  551 Alvarado St  San Francisco  ...     USA   Richvalley        20
#
# [6 rows x 7 columns]

# %%
readcsv.shape
print (readcsv.dtypes)
# Out:
# ID            int64
# Address      object
# City         object
# State        object
# Country      object
# Name         object
# Employees     int64
# dtype: object

# %%
readcsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
# ID           6 non-null int64
# Address      6 non-null object
# City         6 non-null object
# State        6 non-null object
# Country      6 non-null object
# Name         6 non-null object
# Employees    6 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 464.0+ bytes

# %%
readcsv.count()
# Out:
# ID           6
# Address      6
# City         6
# State        6
# Country      6
# Name         6
# Employees    6
# dtype: int64

# %%
readcsv.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
readcsv.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
readcsv2 = readcsv.set_index('ID')
readcsv2
# Out:
#             Address           City  ...         Name Employees
# ID                                  ...
# 1      3666 21st St  San Francisco  ...      Madeira         8
# 2    735 Dolores St  San Francisco  ...  Bready Shop        15
# 3       332 Hill St  San Francisco  ...  Super River        25
# 4      3995 23rd St  San Francisco  ...   Ben's Shop        10
# 5   1056 Sanchez St  San Francisco  ...      Sanchez        12
# 6   551 Alvarado St  San Francisco  ...   Richvalley        20
#
# [6 rows x 6 columns]

# %%
readcsv.head(2)
# Out:
#    ID         Address           City     State Country         Name  Employees
# 0   1    3666 21st St  San Francisco  CA 94114     USA      Madeira          8
# 1   2  735 Dolores St  San Francisco  CA 94119     USA  Bready Shop         15

# %%
readcsv.tail(2)
# Out:
#    ID          Address           City  ... Country        Name Employees
# 4   5  1056 Sanchez St  San Francisco  ...     USA     Sanchez        12
# 5   6  551 Alvarado St  San Francisco  ...     USA  Richvalley        20
#
# [2 rows x 7 columns]

# %%
import pandas as pd
movies = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/1000%20movies%20data.csv')
movies
# Out:
#      Rank                    Title  ... Revenue (Millions) Metascore
# 0       1  Guardians of the Galaxy  ...             333.13      76.0
# 1       2               Prometheus  ...             126.46      65.0
# 2       3                    Split  ...             138.12      62.0
# 3       4                     Sing  ...             270.32      59.0
# 4       5            Suicide Squad  ...             325.02      40.0
# ..    ...                      ...  ...                ...       ...
# 995   996     Secret in Their Eyes  ...                NaN      45.0
# 996   997          Hostel: Part II  ...              17.54      46.0
# 997   998   Step Up 2: The Streets  ...              58.01      50.0
# 998   999             Search Party  ...                NaN      22.0
# 999  1000               Nine Lives  ...              19.64      11.0
#
# [1000 rows x 12 columns]

# %%
movies.info
# Out:
# <bound method DataFrame.info of      Rank                    Title  ... Revenue (Millions) Metascore
# 0       1  Guardians of the Galaxy  ...             333.13      76.0
# 1       2               Prometheus  ...             126.46      65.0
# 2       3                    Split  ...             138.12      62.0
# 3       4                     Sing  ...             270.32      59.0
# 4       5            Suicide Squad  ...             325.02      40.0
# ..    ...                      ...  ...                ...       ...
# 995   996     Secret in Their Eyes  ...                NaN      45.0
# 996   997          Hostel: Part II  ...              17.54      46.0
# 997   998   Step Up 2: The Streets  ...              58.01      50.0
# 998   999             Search Party  ...                NaN      22.0
# 999  1000               Nine Lives  ...              19.64      11.0
#
# [1000 rows x 12 columns]>

# %%
import pandas_profiling
import pandas as pd
import numpy as np

# %%
from pandas_profiling import ProfileReport

# %%
profile = pandas_profiling.ProfileReport(movies)
profile
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...

# %%
#profile.to_file(outputfile='profile.html')
#profile.to_file(output_file='your report.html')
profile.to_file(outputfile="./report.html")
